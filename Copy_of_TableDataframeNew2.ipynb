# %% [markdown]
# <a href="https://colab.research.google.com/github/IgBell/for-Colab/blob/main/Copy_of_TableDataframeNew2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
#from google.colab.patches import cv2_imshow
#from google.colab import files

# Makes a request to the url
url="https://www.sec.gov/Archives/edgar/data/1541617/000154161721000009/xslForm13F_X01/altcap13f3q21infotable.xml"
# Makes a request to the url
#url="https://www.sec.gov/Archives/edgar/data/1541617/000154161721000009/xslForm13F_X01/altcap13f3q21infotable.xml"
#url="https://www.sec.gov/Archives/edgar/data/949012/000139834421021543/xslForm13F_X01/fp0069452_13fhr-table.xml"
#request = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
request = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
# Pass the html response into read_html
tables = pd.read_html(request.text)
#tables = pd.read_html(request.text)
#df.drop(['InvoiceNo'],axis=1,inplace = True)  
#df.drop([2],inplace = True)

df = tables[3] 



df.drop(df.index[[0,1,2]], inplace=True) # удаляем строки
df.drop([1,2,5,6,7,8,9,10,11],axis=1,inplace = True) # удаляем столбцы

#del df[1] столбцы можно и так удалить
#df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-37b967740196> in <module>()
#      14 request = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
#      15 # Pass the html response into read_html
# ---> 16 tables = pd.read_html(request.text)
#      17 #tables = pd.read_html(request.text)
#      18 #df.drop(['InvoiceNo'],axis=1,inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     915             break
#     916     else:
# --> 917         raise retained
#     918
#     919     ret = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     545
#     546         if not tables:
# --> 547             raise ValueError("No tables found")
#     548
#     549         result = []
#
# ValueError: No tables found

# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt

# Makes a request to the url
url="https://www.sec.gov/Archives/edgar/data/1541617/000154161721000009/xslForm13F_X01/altcap13f3q21infotable.xml"
#url="https://www.sec.gov/Archives/edgar/data/949012/000139834421021543/xslForm13F_X01/fp0069452_13fhr-table.xml"
request = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})

# Pass the html response into read_html
tables = pd.read_html(request.text)
#df.drop(['InvoiceNo'],axis=1,inplace = True)  
#df.drop([2],inplace = True)

df = tables[3] 



df.drop(df.index[[0,1,2]], inplace=True) # удаляем строки
df.drop([1,2,5,6,7,8,9,10,11],axis=1,inplace = True) # удаляем столбцы

#del df[1] столбцы можно и так удалить
#df.drop(df.columns[[0, 4, 2]], axis = 1, inplace = True) или по инлексу даже если есть лабелс
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-1799a9f885b8> in <module>()
#      10
#      11 # Pass the html response into read_html
# ---> 12 tables = pd.read_html(request.text)
#      13 #df.drop(['InvoiceNo'],axis=1,inplace = True)
#      14 #df.drop([2],inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     915             break
#     916     else:
# --> 917         raise retained
#     918
#     919     ret = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     545
#     546         if not tables:
# --> 547             raise ValueError("No tables found")
#     548
#     549         result = []
#
# ValueError: No tables found

# %%
uploaded = files.upload()

filename = next(iter(uploaded))
#tickers = read_file(filename)
# Out:
#      <input type="file" id="files-c5f12e11-31f3-46bc-9f2a-6d8c91cd13c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5f12e11-31f3-46bc-9f2a-6d8c91cd13c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AllTickers.csv to AllTickers (2).csv

# %%
dfcsv=pd.read_csv('AllTickers.csv')

# %%
#dfcsv

# %%
dfcsv.drop(['Last Sale', 'Net Change', '% Change',  'Country', 'IPO Year', 'Volume', 'Sector', 'Industry;'],1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3857331f969d> in <module>()
# ----> 1 dfcsv.drop(['Last Sale', 'Net Change', '% Change',  'Country', 'IPO Year', 'Volume', 'Sector', 'Industry;'],1,inplace=True)
#
# NameError: name 'dfcsv' is not defined

# %%
dfex
# Out:
#        Yahoo Stock Tickers                       Unnamed: 1
# 4                     AAPL                       Apple Inc.
# 5                      BAC      Bank of America Corporation
# 6                     AMZN                 Amazon.com, Inc.
# 7                        T                        AT&T Inc.
# 8                     GOOG                    Alphabet Inc.
# ...                    ...                              ...
# 106326              G5N.SG  Groupon Inc. Reg. Shares DL-,00
# 106327              N1H.AX              N1 Holdings Limited
# 106328              1K2.BE          K2M GROUP HLDGS DL-,001
# 106329              2RM.BE         RE/MAX HLDGS A DL -,0001
# 106330               2RM.F            RE/MAX Holdings, Inc.
#
# [106327 rows x 2 columns]

# %%
df[0].value_counts()
# Out:
# ALIBABA GROUP HLDG LTD                    1
# QUALTRICS INTL INC                        1
# MICROSOFT CORP                            1
# PINDUODUO INC                             1
# ROBLOX CORP                               1
# CONFLUENT INC                             1
# MONEYLION INC                             1
# TOAST INC                                 1
# FARFETCH LTD                              1
# UIPATH INC                                1
# CROWDSTRIKE HLDS INC                      1
# SHOPIFY INC                               1
# ZOOM VIDEO COMMUNICATIONS IN              1
# OPENDOOR TECHNOLOGIES INC                 1
# PELOTON INTERACTIVE INC                   1
# MONDAY COM LTD                            1
# CAZOO GROUP LTD                           1
# BOOKING HLDGS INC                         1
# SEA LTD                                   1
# FACEBOOK INC                              1
# CCC INTELLIGENT SOLUTIONS HOLDINGS INC    1
# UNITY SOFTWARE INC                        1
# SNOWFLAKE INC                             1
# 23ANDME HOLDING CO                        1
# OKTA INC                                  1
# COUPANG INC                               1
# DUOLINGO INC                              1
# UBER TECHNOLOGIES INC                     1
# ALTIMETER GROWTH CORP                     1
# AMAZON COM INC                            1
# BUMBLE INC                                1
# Name: 0, dtype: int64

# %%
df[3] = pd.to_numeric(df[3], errors='coerce') # ВАЖНО!!! конвертируем столбец в числовое значение
df[4] = pd.to_numeric(df[4], errors='coerce')
df.groupby([0])
df.sort_values([3],ascending=False, inplace=True) # сортируем по данному столбцу в порядке убывания
df[5]=df[3]/df[4]*1000 #стоимость одной акции на дату отчета
#FamousNames = df[0].tolist()
#df = df.set_index(0)
df
# Out:
#                                          0        3         4            5
# 28                           SNOWFLAKE INC  6362321  21037333   302.430018
# 14                            FACEBOOK INC  1273866   3753400   339.389887
# 31                   UBER TECHNOLOGIES INC  1097600  24500000    44.800000
# 19                          MICROSOFT CORP   497063   1763135   281.919989
# 24                 PELOTON INTERACTIVE INC   491833   5650000    87.050088
# 21               OPENDOOR TECHNOLOGIES INC   275102  13400000    20.530000
# 27                             SHOPIFY INC   271156    200000  1355.780000
# 30                      UNITY SOFTWARE INC   264895   2098175   126.250194
# 33            ZOOM VIDEO COMMUNICATIONS IN   248425    950000   261.500000
# 11                    CROWDSTRIKE HLDS INC   238407    970000   245.780412
# 25                             ROBLOX CORP   215318   2850000    75.550175
# 5                   ALIBABA GROUP HLDG LTD   170554   1152000   148.050347
# 22                              UIPATH INC   158082   3004790    52.609999
# 15                            FARFETCH LTD   141652   3779409    37.479934
# 20                                OKTA INC   124604    525000   237.340952
# 9                            CONFLUENT INC   102896   1725000    59.649855
# 26                                 SEA LTD    95619    300000   318.730000
# 4                           AMAZON COM INC    82278     25045  3285.206628
# 10                             COUPANG INC    73604   2642857    27.850164
# 7                               BUMBLE INC    52479   1050000    49.980000
# 23                           PINDUODUO INC    51863    572000    90.669580
# 32                      QUALTRICS INTL INC    42740   1000000    42.740000
# 18                          MONDAY COM LTD    32620    100000   326.200000
# 6                        BOOKING HLDGS INC    25405     10702  2373.855354
# 29                               TOAST INC    24975    500000    49.950000
# 16                      23ANDME HOLDING CO    24645   2720243     9.059852
# 13                            DUOLINGO INC    20795    125000   166.360000
# 12                         CAZOO GROUP LTD    11655   1500000     7.770000
# 17                           MONEYLION INC     6770   1000000     6.770000
# 8   CCC INTELLIGENT SOLUTIONS HOLDINGS INC     3416    325000    10.510769
# 3                    ALTIMETER GROWTH CORP      102     10000    10.200000

# %%
FamousNames = df[0].tolist()
FamousNames
# Out:
# ['SNOWFLAKE INC',
#  'FACEBOOK INC',
#  'UBER TECHNOLOGIES INC',
#  'MICROSOFT CORP',
#  'PELOTON INTERACTIVE INC',
#  'OPENDOOR TECHNOLOGIES INC',
#  'SHOPIFY INC',
#  'UNITY SOFTWARE INC',
#  'ZOOM VIDEO COMMUNICATIONS IN',
#  'CROWDSTRIKE HLDS INC',
#  'ROBLOX CORP',
#  'ALIBABA GROUP HLDG LTD',
#  'UIPATH INC',
#  'FARFETCH LTD',
#  'OKTA INC',
#  'CONFLUENT INC',
#  'SEA LTD',
#  'AMAZON COM INC',
#  'COUPANG INC',
#  'BUMBLE INC',
#  'PINDUODUO INC',
#  'QUALTRICS INTL INC',
#  'MONDAY COM LTD',
#  'BOOKING HLDGS INC',
#  'TOAST INC',
#  '23ANDME HOLDING CO',
#  'DUOLINGO INC',
#  'CAZOO GROUP LTD',
#  'MONEYLION INC',
#  'CCC INTELLIGENT SOLUTIONS HOLDINGS INC',
#  'ALTIMETER GROWTH CORP']

# %%
df = df.set_index(0)
plt.figure(figsize=(16,8))
df[3][df.index[0:20]].plot(kind='pie',fontsize=10)# выбираем колонку,строки (первые 12) и размер шрифта
plt.ylabel('',fontsize=18) # удаляем или новое название графика справа не по названию колонки
plt.text(-2,1, "можно написать текст")#можно по указанным координатам раположить поясняющий текст
plt.show()

# %%
import pandas as pd
import requests
import json
companies=['SNOW','FB','UBER','MSFT','PTON','OPEN']
#ticker="A"
price=[]
for ticker in companies:
    response = requests.get(f"https://query2.finance.yahoo.com/v7/finance/quote?symbols={ticker}", headers={"User-Agent": "Mozilla/5.0"})
    page=response.text
    parsed_string = json.loads(page)
    price.append(parsed_string['quoteResponse']['result'][0]['regularMarketPrice'])
df1=pd.DataFrame(companies)
df1[1]=price
df1[1] = pd.to_numeric(df1[1], errors='coerce')
#df1.index = companies
df1
df1
# Out:
#       0       1
# 0  SNOW  349.22
# 1    FB  335.24
# 2  UBER   43.91
# 3  MSFT  334.69
# 4  PTON   38.59
# 5  OPEN   14.89

# %%
#df[6]=df1.loc[0,1]
#df[7]=df1.loc[0,0]
#df
#df.loc[:, "E"] = list("abcd")

# %%
fullname=['SNOWFLAKE INC','FACEBOOK INC','UBER TECHNOLOGIES INC','MICROSOFT CORP','PELOTON INTERACTIVE INC','OPENDOOR TECHNOLOGIES INC']

#df1.index=FamousNames
df1.index=fullname
df1.drop([0],1,inplace=True)

df1
# Out:
#                                 1
# SNOWFLAKE INC              349.22
# FACEBOOK INC               335.24
# UBER TECHNOLOGIES INC       43.91
# MICROSOFT CORP             334.69
# PELOTON INTERACTIVE INC     38.59
# OPENDOOR TECHNOLOGIES INC   14.89

# %%
df3=pd.concat([df,df1],axis=1)
df3[6]=(df3[1]-df3[5])/df3[5]*100
df3
# Out:
#                                               3         4  ...       1          6
# SNOWFLAKE INC                           6362321  21037333  ...  349.22  15.471342
# FACEBOOK INC                            1273866   3753400  ...  335.24  -1.222749
# UBER TECHNOLOGIES INC                   1097600  24500000  ...   43.91  -1.986607
# MICROSOFT CORP                           497063   1763135  ...  334.69  18.718081
# PELOTON INTERACTIVE INC                  491833   5650000  ...   38.59 -55.669201
# OPENDOOR TECHNOLOGIES INC                275102  13400000  ...   14.89 -27.471992
# SHOPIFY INC                              271156    200000  ...     NaN        NaN
# UNITY SOFTWARE INC                       264895   2098175  ...     NaN        NaN
# ZOOM VIDEO COMMUNICATIONS IN             248425    950000  ...     NaN        NaN
# CROWDSTRIKE HLDS INC                     238407    970000  ...     NaN        NaN
# ROBLOX CORP                              215318   2850000  ...     NaN        NaN
# ALIBABA GROUP HLDG LTD                   170554   1152000  ...     NaN        NaN
# UIPATH INC                               158082   3004790  ...     NaN        NaN
# FARFETCH LTD                             141652   3779409  ...     NaN        NaN
# OKTA INC                                 124604    525000  ...     NaN        NaN
# CONFLUENT INC                            102896   1725000  ...     NaN        NaN
# SEA LTD                                   95619    300000  ...     NaN        NaN
# AMAZON COM INC                            82278     25045  ...     NaN        NaN
# COUPANG INC                               73604   2642857  ...     NaN        NaN
# BUMBLE INC                                52479   1050000  ...     NaN        NaN
# PINDUODUO INC                             51863    572000  ...     NaN        NaN
# QUALTRICS INTL INC                        42740   1000000  ...     NaN        NaN
# MONDAY COM LTD                            32620    100000  ...     NaN        NaN
# BOOKING HLDGS INC                         25405     10702  ...     NaN        NaN
# TOAST INC                                 24975    500000  ...     NaN        NaN
# 23ANDME HOLDING CO                        24645   2720243  ...     NaN        NaN
# DUOLINGO INC                              20795    125000  ...     NaN        NaN
# CAZOO GROUP LTD                           11655   1500000  ...     NaN        NaN
# MONEYLION INC                              6770   1000000  ...     NaN        NaN
# CCC INTELLIGENT SOLUTIONS HOLDINGS INC     3416    325000  ...     NaN        NaN
# ALTIMETER GROWTH CORP                       102     10000  ...     NaN        NaN
#
# [31 rows x 5 columns]
